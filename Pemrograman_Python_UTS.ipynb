# %% [markdown]
# Ujian Tengah Semester 2
#
# 1.   Nama          : Josia Given Santoso
# 2.   Kelas         : 2PDS1
# 3.   Tanggal       : 26 Maret 2024
# 4.   Mata Kuliah   : Bahasa Pemrograman Python

# %% [markdown]
# 1. Jelaskan 4 struktur data didalam python beserta contohnya, yaitu
# *   List
# *   Tuple
# *   Dictionary
# *   Sets
#
# Jawab
#
# - List merupakan struktur data yang nilai atau koleksi didalam nya bisa diubah  secara langsung oleh pengguna.
# List dapat menyimpan beberapa tipe data seperti
# a) string
# b) integer
# c) boolean
# d) nested list
# e) nested tuple
#
# - Tuple merupakan struktur data yang isi nya tidak dapat dirubah oleh pengguna ketika sudah dibuat. Tuple juga bersifat terstuktur dan terurut. Tuple didefinisikan sama seperti list.
#
# - Dictionary merupakan struktur data python yang memungkinkan tipe data tersebut berisi suatu kunci yang memiliki nilai (Key dan Value)
#
# - Set merupakan struktur data yang berisi nilai tetap. Nilai dalam sets tidak boleh ada duplikat dan harus merupakan nilai yang urut. Set digunakan untuk menyimpan koleksi nilai dari tipe data lain seperti list, tuple dan sebagai nya.

# %%
list_buah           = ["apel", "mangga", "Jambu", "klengkeng"]

tuple_nama_siswa    = ("Joko", "Udin", "Saepudin", "Bambang")
a, b, c, d = tuple_nama_siswa
print("\n=============================\n")
print("Nama Siswa yang terdapat dalam Tuple adalah", tuple_nama_siswa)

print(a)
print(b)
print(c)
print(c)

dictionary_ID_siswa = {'Joko': 1542, 'Udin': 256, 'Saepudin': 144, 'Bambang': '357' }
set_nomor_urut      = {1, 2, 3, 4}

print("\n=============================\n")
print("Nama Buah-buahan yang terdapat dalam list adalah", list_buah)

print("\n=============================\n")
print("Nama Key dan Value yang terdapat dalam Dictionary adalah", dictionary_ID_siswa)

print("Nama dan ID Siswa", ['Joko'], "adalah")
print("\n=============================\n")

print("Urutan dalam set yang dibuat adalah ", set_nomor_urut)
print("\n=============================\n")
# Out:
# =============================
#
# Nama Siswa yang terdapat dalam Tuple adalah ('Joko', 'Udin', 'Saepudin', 'Bambang')
# Joko
# Udin
# Saepudin
# Saepudin
#
# =============================
#
# Nama Buah-buahan yang terdapat dalam list adalah ['apel', 'mangga', 'Jambu', 'klengkeng']
#
# =============================
#
# Nama Key dan Value yang terdapat dalam Dictionary adalah {'Joko': 1542, 'Udin': 256, 'Saepudin': 144, 'Bambang': '357'}
# Nama dan ID Siswa ['Joko'] adalah
#
# =============================
#
# Urutan dalam set yang dibuat adalah  {1, 2, 3, 4}
#
# =============================

# %% [markdown]
# 2.

# %%
# Mengimport library yang dibutuhkan untuk proyek ini
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
from matplotlib import pyplot as plt

#Digunakan untuk mencetak ouput dengan lebih rapi
from IPython.display import display

# %%
#2.1 Data Exploration

#Mengambil URL dari dataset csv yang disediakan
url = "https://raw.githubusercontent.com/itsmecevi/dataset/main/cardataset_small.csv"

# Menggunakan pandas untuk membaca dataset dari url dengan format CSV
df = pd.read_csv(url)

# Mencetak hanya 3 baris data pertama dari dataframe
df.head(3)

# Memberikan ringkasan secara langsung tiap kolom
df.describe()

# Membersihkan nilai yang hilang
df = df.dropna()

# %%
### Melakukan standarisi kolom, berfungsi agar dataframe tersebut memiliki standar yang konsisten.
df.columns = df.columns.str.lower().str.replace(' ', '_') # Mengganti nilai data kosong dengan "-" khusus tipe data String
string_columns = list(df.dtypes[df.dtypes == 'object'].index)
for col in string_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
print("Nilai rata=-rata kolom MSRP adalah :", df['msrp'].mean()) # Mengitung Nilai Rata rata
print("Nilai Median kolom MSRP adalah :", df['msrp'].median()) # Mengitung Nilai Tengah
print("Nilai Maksimum kolom MSRP adalah :", df['msrp'].max()) # Mengitung Nilai Maksimum
print("Nilai Minimum kolom MSRP adalah :", df['msrp'].min()) # Mengitung Nilai Minimum
print("Modus kolom MSRP adalah :", df['msrp'].mode()) # Mengitung Nilai Modus
# Out:
# Nilai rata=-rata kolom MSRP adalah : 53457.607463222106
# Nilai Median kolom MSRP adalah : 36020.0
# Nilai Maksimum kolom MSRP adalah : 548800
# Nilai Minimum kolom MSRP adalah : 2000
# Modus kolom MSRP adalah : 0    2000
# Name: msrp, dtype: int64

# %% [markdown]
# **Soal Nomor 2.2 Filtering and Selection**

# %%
"""

Soal Nomor 2.2 Filtering and Selection

"""
### Melihat ada berapa nilai Unik dari kolom X (model)
jumlah_unique = df['model'].nunique()
print("Jumlah unique values dari column X:", jumlah_unique)
print("\n=============================\n")
print()

### Menampilkan mobil dengan model Civic
kriteria_x = df[(df['model'] == 'civic')] #
display(kriteria_x)

print("\n=============================\n")

### Menampilkan harga MSRP lebih dari 50000
X2 = 50000 # Kriteria nilai MSRP yang tertera pada soal.
print("Data mobil dengan MSRP lebih dari", "$",X2, "adalah:")
print("\n=============================\n")
display(df[df['msrp'] > X2])
print()

### Menampilkan mobil dengan 4 silinder dan 4 pintu
kriteria_khusus = df[(df['engine_cylinders'] == 4.0) & (df['number_of_doors'] == 4.0)] # Menentukan dua kriteria khusus yang harus terpenuhi
print("\n=============================\n")
display(kriteria_khusus)
# Out:
# Jumlah unique values dari column X: 239
#
# =============================
#        make  model  year                engine_fuel_type  engine_hp  \
# 2546  honda  civic  2015     premium_unleaded_(required)      205.0
# 2547  honda  civic  2015                regular_unleaded      110.0
# 2548  honda  civic  2015     premium_unleaded_(required)      205.0
# 2550  honda  civic  2015     premium_unleaded_(required)      205.0
# 2552  honda  civic  2015                regular_unleaded      110.0
# 2553  honda  civic  2015     premium_unleaded_(required)      205.0
# 2555  honda  civic  2015     premium_unleaded_(required)      205.0
# 2557  honda  civic  2015                regular_unleaded      110.0
# 2558  honda  civic  2015                regular_unleaded      110.0
# 2564  honda  civic  2015     premium_unleaded_(required)      205.0
# 2567  honda  civic  2015     premium_unleaded_(required)      205.0
# 2586  honda  civic  2017                regular_unleaded      174.0
# 2587  honda  civic  2017  premium_unleaded_(recommended)      180.0
# 2588  honda  civic  2017                regular_unleaded      174.0
# 2589  honda  civic  2017                regular_unleaded      174.0
# 2590  honda  civic  2017                regular_unleaded      174.0
# 2591  honda  civic  2017  premium_unleaded_(recommended)      180.0
# 2592  honda  civic  2017                regular_unleaded      174.0
# 2593  honda  civic  2017                regular_unleaded      174.0
# 2594  honda  civic  2017                regular_unleaded      174.0
# 2595  honda  civic  2017                regular_unleaded      174.0
# 2596  honda  civic  2017                regular_unleaded      174.0
# 2597  honda  civic  2017                regular_unleaded      174.0
# 2601  honda  civic  2017                regular_unleaded      174.0
# 2602  honda  civic  2017                regular_unleaded      174.0
# 2603  honda  civic  2017                regular_unleaded      174.0
# 2609  honda  civic  2017                regular_unleaded      174.0
# 2610  honda  civic  2017                regular_unleaded      174.0
#
#       engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 2546               4.0            manual  front_wheel_drive              4.0
# 2547               4.0         automatic  front_wheel_drive              4.0
# 2548               4.0            manual  front_wheel_drive              2.0
# 2550               4.0            manual  front_wheel_drive              2.0
# 2552               4.0         automatic  front_wheel_drive              4.0
# 2553               4.0            manual  front_wheel_drive              2.0
# 2555               4.0            manual  front_wheel_drive              4.0
# 2557               4.0         automatic  front_wheel_drive              4.0
# 2558               4.0         automatic  front_wheel_drive              4.0
# 2564               4.0            manual  front_wheel_drive              2.0
# 2567               4.0            manual  front_wheel_drive              4.0
# 2586               4.0            manual  front_wheel_drive              4.0
# 2587               4.0            manual  front_wheel_drive              4.0
# 2588               4.0         automatic  front_wheel_drive              4.0
# 2589               4.0         automatic  front_wheel_drive              4.0
# 2590               4.0         automatic  front_wheel_drive              4.0
# 2591               4.0         automatic  front_wheel_drive              4.0
# 2592               4.0         automatic  front_wheel_drive              4.0
# 2593               4.0         automatic  front_wheel_drive              2.0
# 2594               4.0         automatic  front_wheel_drive              4.0
# 2595               4.0         automatic  front_wheel_drive              2.0
# 2596               4.0         automatic  front_wheel_drive              4.0
# 2597               4.0            manual  front_wheel_drive              4.0
# 2601               4.0         automatic  front_wheel_drive              2.0
# 2602               4.0         automatic  front_wheel_drive              4.0
# 2603               4.0         automatic  front_wheel_drive              4.0
# 2609               4.0         automatic  front_wheel_drive              4.0
# 2610               4.0            manual  front_wheel_drive              2.0
#
#                 market_category vehicle_size  vehicle_style  highway_mpg  \
# 2546  factory_tuner,performance      compact          sedan           31
# 2547                     hybrid      compact          sedan           47
# 2548  factory_tuner,performance      compact          coupe           31
# 2550  factory_tuner,performance      compact          coupe           31
# 2552                     hybrid      compact          sedan           47
# 2553  factory_tuner,performance      compact          coupe           31
# 2555  factory_tuner,performance      compact          sedan           31
# 2557                     hybrid      compact          sedan           47
# 2558                     hybrid      compact          sedan           47
# 2564  factory_tuner,performance      compact          coupe           31
# 2567  factory_tuner,performance      compact          sedan           31
# 2586                  hatchback      compact  4dr_hatchback           39
# 2587      hatchback,performance      compact  4dr_hatchback           39
# 2588      hatchback,performance      compact  4dr_hatchback           40
# 2589      hatchback,performance      compact  4dr_hatchback           40
# 2590                  hatchback      compact  4dr_hatchback           40
# 2591      hatchback,performance      compact  4dr_hatchback           36
# 2592                performance      midsize          sedan           42
# 2593                performance      compact          coupe           40
# 2594                performance      midsize          sedan           42
# 2595                performance      compact          coupe           40
# 2596                performance      midsize          sedan           42
# 2597                performance      midsize          sedan           42
# 2601                performance      compact          coupe           40
# 2602                performance      midsize          sedan           42
# 2603                performance      midsize          sedan           42
# 2609                performance      midsize          sedan           42
# 2610                performance      compact          coupe           41
#
#       city_mpg  popularity   msrp
# 2546        22        2202  24590
# 2547        44        2202  27435
# 2548        22        2202  23090
# 2550        22        2202  22890
# 2552        44        2202  25935
# 2553        22        2202  24390
# 2555        22        2202  23290
# 2557        44        2202  26235
# 2558        44        2202  24735
# 2564        22        2202  24590
# 2567        22        2202  23090
# 2586        30        2202  19700
# 2587        30        2202  21300
# 2588        31        2202  25300
# 2589        31        2202  22800
# 2590        31        2202  20500
# 2591        30        2202  22100
# 2592        32        2202  26600
# 2593        31        2202  26225
# 2594        32        2202  22300
# 2595        31        2202  23525
# 2596        32        2202  23800
# 2597        31        2202  21500
# 2601        31        2202  22400
# 2602        32        2202  23300
# 2603        32        2202  24800
# 2609        32        2202  24800
# 2610        30        2202  21600
# =============================
#
# Data mobil dengan MSRP lebih dari $ 50000 adalah:
#
# =============================
#          make     model  year                engine_fuel_type  engine_hp  \
# 49        bmw  2_series  2016     premium_unleaded_(required)      320.0
# 52        bmw  2_series  2017  premium_unleaded_(recommended)      335.0
# 132       bmw  3_series  2015     premium_unleaded_(required)      335.0
# 294   ferrari       360  2002     premium_unleaded_(required)      400.0
# 295   ferrari       360  2002     premium_unleaded_(required)      400.0
# ...       ...       ...   ...                             ...        ...
# 3913    lotus     elise  2009     premium_unleaded_(required)      218.0
# 3916    lotus     elise  2010     premium_unleaded_(required)      218.0
# 3917    lotus     elise  2011     premium_unleaded_(required)      189.0
# 3918    lotus     elise  2011     premium_unleaded_(required)      217.0
# 3919    lotus     elise  2011     premium_unleaded_(required)      217.0
#
#       engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 49                 6.0         automatic  rear_wheel_drive              2.0
# 52                 6.0         automatic   all_wheel_drive              2.0
# 132                6.0         automatic  rear_wheel_drive              4.0
# 294                8.0            manual  rear_wheel_drive              2.0
# 295                8.0            manual  rear_wheel_drive              2.0
# ...                ...               ...               ...              ...
# 3913               4.0            manual  rear_wheel_drive              2.0
# 3916               4.0            manual  rear_wheel_drive              2.0
# 3917               4.0            manual  rear_wheel_drive              2.0
# 3918               4.0            manual  rear_wheel_drive              2.0
# 3919               4.0            manual  rear_wheel_drive              2.0
#
#                             market_category vehicle_size vehicle_style  \
# 49    factory_tuner,luxury,high-performance      compact   convertible
# 52    factory_tuner,luxury,high-performance      compact   convertible
# 132          luxury,high-performance,hybrid      midsize         sedan
# 294                 exotic,high-performance      compact   convertible
# 295                 exotic,high-performance      compact         coupe
# ...                                     ...          ...           ...
# 3913                exotic,high-performance      compact   convertible
# 3916                exotic,high-performance      compact   convertible
# 3917                exotic,high-performance      compact   convertible
# 3918                exotic,high-performance      compact   convertible
# 3919                exotic,high-performance      compact   convertible
#
#       highway_mpg  city_mpg  popularity    msrp
# 49             30        20        3916   50750
# 52             32        21        3916   51050
# 132            33        25        3916   50150
# 294            15        10        2774  160829
# 295            15        10        2774  140615
# ...           ...       ...         ...     ...
# 3913           26        20         613   54990
# 3916           26        20         613   54990
# 3917           27        21         613   51845
# 3918           26        20         613   54990
# 3919           26        20         613   57950
#
# [707 rows x 16 columns]
# =============================
#                make      model  year                engine_fuel_type  \
# 35    mercedes-benz  190-class  1991                regular_unleaded
# 38    mercedes-benz  190-class  1992                regular_unleaded
# 39    mercedes-benz  190-class  1993                regular_unleaded
# 64         chrysler        200  2015        flex-fuel_(unleaded/e85)
# 65         chrysler        200  2015        flex-fuel_(unleaded/e85)
# ...             ...        ...   ...                             ...
# 3981          buick   envision  2017  premium_unleaded_(recommended)
# 3982          buick   envision  2017        flex-fuel_(unleaded/e85)
# 3983          buick   envision  2017  premium_unleaded_(recommended)
# 3984          buick   envision  2017        flex-fuel_(unleaded/e85)
# 3985          buick   envision  2017        flex-fuel_(unleaded/e85)
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 35        130.0               4.0            manual   rear_wheel_drive
# 38        130.0               4.0            manual   rear_wheel_drive
# 39        130.0               4.0            manual   rear_wheel_drive
# 64        184.0               4.0         automatic  front_wheel_drive
# 65        184.0               4.0         automatic  front_wheel_drive
# ...         ...               ...               ...                ...
# 3981      252.0               4.0         automatic    all_wheel_drive
# 3982      197.0               4.0         automatic  front_wheel_drive
# 3983      252.0               4.0         automatic    all_wheel_drive
# 3984      197.0               4.0         automatic    all_wheel_drive
# 3985      197.0               4.0         automatic  front_wheel_drive
#
#       number_of_doors      market_category vehicle_size vehicle_style  \
# 35                4.0               luxury      compact         sedan
# 38                4.0               luxury      compact         sedan
# 39                4.0               luxury      compact         sedan
# 64                4.0            flex_fuel      midsize         sedan
# 65                4.0            flex_fuel      midsize         sedan
# ...               ...                  ...          ...           ...
# 3981              4.0            crossover      midsize       4dr_suv
# 3982              4.0  crossover,flex_fuel      midsize       4dr_suv
# 3983              4.0            crossover      midsize       4dr_suv
# 3984              4.0  crossover,flex_fuel      midsize       4dr_suv
# 3985              4.0  crossover,flex_fuel      midsize       4dr_suv
#
#       highway_mpg  city_mpg  popularity   msrp
# 35             26        18         617   2000
# 38             26        18         617   2000
# 39             26        18         617   2000
# 64             36        23        1013  25170
# 65             36        23        1013  23950
# ...           ...       ...         ...    ...
# 3981           26        20         155  44960
# 3982           29        22         155  35870
# 3983           26        20         155  42320
# 3984           28        21         155  37720
# 3985           29        22         155  37720
#
# [778 rows x 16 columns]

# %% [markdown]
# **Soal Nomor 2.3 Data Manipulation**

# %%
"""

Soal Nomor 2.3 Data Manipulation

"""

#### Menghitung efisiensi bahan Bakar (MPG). Berdasarkan hasil rata rata City_MPG dan Highway_MPG
print("\n=============================\n")
df['Efisiensi_MPG_rata_rata'] = (df['city_mpg'] + df['highway_mpg']) / 2
print("Kolom 'Efisiensi_MPG_rata_rata' berhasil ditambahkan.")

### Mengubah nama kolom "Engine HP" menjadi "Horsepower"
print("\n=============================\n")
df.rename(columns={'engine_hp': 'horsepower'}, inplace=True) # Mengunakan fungsi rename untuk mengubah nama kolom
print("Nama kolom 'engine_hp' telah diganti menjadi 'horsepower' ")

### Menghapus kolom "Market Category" menggunakan metode Drop
print("\n=============================\n")
df.drop(columns='market_category', inplace=True) # Mengunakan fungsi drop untuk menghapus kolom
print("Nama kolom 'market category' telah dihapus")
print("=============================\n")
print()

# Mencetak semua perubahan yang telah dibuat sebagai dataframe
print("Menampilkan hasil akhir perubahan dataframe yang telah dibuat")
print("\n=============================\n")
display(df)
# Out:
# =============================
#
# Kolom 'Efisiensi_MPG_rata_rata' berhasil ditambahkan.
#
# =============================
#
# Nama kolom 'engine_hp' telah diganti menjadi 'horsepower'
#
# =============================
#
# Nama kolom 'market category' telah dihapus
# =============================
#
#
# Menampilkan hasil akhir perubahan dataframe yang telah dibuat
#
# =============================
#        make       model  year                engine_fuel_type  horsepower  \
# 0       bmw  1_series_m  2011     premium_unleaded_(required)       335.0
# 1       bmw    1_series  2011     premium_unleaded_(required)       300.0
# 2       bmw    1_series  2011     premium_unleaded_(required)       300.0
# 3       bmw    1_series  2011     premium_unleaded_(required)       230.0
# 4       bmw    1_series  2011     premium_unleaded_(required)       230.0
# ...     ...         ...   ...                             ...         ...
# 3981  buick    envision  2017  premium_unleaded_(recommended)       252.0
# 3982  buick    envision  2017        flex-fuel_(unleaded/e85)       197.0
# 3983  buick    envision  2017  premium_unleaded_(recommended)       252.0
# 3984  buick    envision  2017        flex-fuel_(unleaded/e85)       197.0
# 3985  buick    envision  2017        flex-fuel_(unleaded/e85)       197.0
#
#       engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0                  6.0            manual   rear_wheel_drive              2.0
# 1                  6.0            manual   rear_wheel_drive              2.0
# 2                  6.0            manual   rear_wheel_drive              2.0
# 3                  6.0            manual   rear_wheel_drive              2.0
# 4                  6.0            manual   rear_wheel_drive              2.0
# ...                ...               ...                ...              ...
# 3981               4.0         automatic    all_wheel_drive              4.0
# 3982               4.0         automatic  front_wheel_drive              4.0
# 3983               4.0         automatic    all_wheel_drive              4.0
# 3984               4.0         automatic    all_wheel_drive              4.0
# 3985               4.0         automatic  front_wheel_drive              4.0
#
#      vehicle_size vehicle_style  highway_mpg  city_mpg  popularity   msrp  \
# 0         compact         coupe           26        19        3916  46135
# 1         compact   convertible           28        19        3916  40650
# 2         compact         coupe           28        20        3916  36350
# 3         compact         coupe           28        18        3916  29450
# 4         compact   convertible           28        18        3916  34500
# ...           ...           ...          ...       ...         ...    ...
# 3981      midsize       4dr_suv           26        20         155  44960
# 3982      midsize       4dr_suv           29        22         155  35870
# 3983      midsize       4dr_suv           26        20         155  42320
# 3984      midsize       4dr_suv           28        21         155  37720
# 3985      midsize       4dr_suv           29        22         155  37720
#
#       Efisiensi_MPG_rata_rata
# 0                        22.5
# 1                        23.5
# 2                        24.0
# 3                        23.0
# 4                        23.0
# ...                       ...
# 3981                     23.0
# 3982                     25.5
# 3983                     23.0
# 3984                     24.5
# 3985                     25.5
#
# [2787 rows x 16 columns]

# %% [markdown]
# **Soal Nomor 2.4 Statistical Analysis**

# %%
"""

Soal Nomor 2.4 Statistical Analysis

"""
# Menghitung korelasi antara kolom "engine HP" yang sudah diubah menjadi horsepower, dengan MSRP
display("Korelasi")
korelasi = df['msrp'].corr(df['horsepower'])
print("Korelasi antara kolom Horsepower dan MSRP adalah ':", korelasi)
print("\n=============================\n")

# Menghitung jumlah nilai unik mobil dengan tipe transmisi yang berbeda
display("Nilai Unik")
jumlah_unik_transmisi = df['transmission_type'].nunique()
print("Jumlah unique values dari Tipe transmisi mobil adalah :", jumlah_unique)
print("\n=============================\n")

# Menghitung rata rata dan median dari kolom "Popularity"
print("Nilai rata-rata kolom Popularity adalah :", df['msrp'].mean()) #Mengitung Nilai Rata rata
print("Nilai Median kolom Popularity adalah :", df['msrp'].median()) #Mengitung Nilai Tengah
# Out:
# 'Korelasi'
# Korelasi antara kolom Horsepower dan MSRP adalah ': 0.741943956954498
#
# =============================
# 'Nilai Unik'
# Jumlah unique values dari Tipe transmisi mobil adalah : 239
#
# =============================
#
# Nilai rata-rata kolom Popularity adalah : 53457.607463222106
# Nilai Median kolom Popularity adalah : 36020.0

# %% [markdown]
# **Soal Nomor 2.5 Data Visualization**

# %%
"""

Soal Nomor 2.5 Data Visualization

"""

# Membuat histogram untuk kolom 'Engine HP' yang sudah di ubah namanya menjadi kolom 'Horsepower'
plt.figure(figsize=(6, 4)) # Menentukan ukuran dari figure yang akan dibuat
sns.histplot(df.horsepower, bins=40, color='blue', alpha=1) # Menggunakan kolom horsepower dan mengganti warna figure.
plt.ylabel('Frequency') # Sumbu Y adalah frekuensi
plt.xlabel('Horsepower') # Sumbu X adalah nilai dari Horsepower
plt.title('Distribution of Horsepower')

plt.show()

# Membuat scatterplot untuk menampilkan hubungan antar highway MPG dan City MPG
plt.figure(figsize=(6, 4))
plt.scatter(df['city_mpg'], df['highway_mpg'], color='blue')
plt.xlabel('Harga (X)')
plt.ylabel('City MPG (Y)')
plt.title('Scatter Plot Hubungan Harga dan City MPG')
plt.tight_layout()

plt.show()

# Membuat barplot untuk menampilkan jumlah mobil berdasarkan Ukuran Kendaraan "Vehicle Size"
plt.figure(figsize=(6, 4))
sns.histplot(df.vehicle_size, bins=40, color='blue', alpha=1)
plt.ylabel('Frequency')
plt.xlabel('Vehicle Size')
plt.title('Distribution of Vehicle Size')

plt.show()

# %% [markdown]
# **Soal Nomor 3 Upload Hasil UTS ke Email dosen dan kaggle**
